# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# import torch

# %%
# !which python

# %%
import os
# os.chdir('./code_seg/crf_loss')

# %%
# !python3 setup.py install

# %%
# !pip install tensorboardX
# !pip install SimpleITK

# %%
# os.chdir("../..")
os.getcwd()
# Out:
# '/home/kunzixie/Medical_Image_Analysis/SSL_TNBC'

# %%
# !sh run.sh
# Out:
# /home/kunzixie/Medical_Image_Analysis/SSL_TNBC/code_detection
#
# # ------------------------- Options ------------------------- #
#              isTrain: True
#              dataset: TN
#                ratio: 0.1
#                   r1: 14
#                   r2: 28
#       gaussian_sigma: 3.5
#
# *************** model ***************
#                 name: ResUNet34
#           pretrained: True
#                out_c: 1
#
# *************** train ***************
#          random_seed: -1
#             data_dir: ../data_for_train/TN
#        root_save_dir: ../experiments/detection/TN/0.10_repeat=1
#           input_size: 224
#         train_epochs: 80
#           batch_size: 16
#      checkpoint_freq: 100
#                   lr: 0.0001
#         weight_decay: 0.0001
#         log_interval: 30
#              workers: 1
#                 gpus: [0]
#              img_dir: ../data_for_train/TN/images
#            label_dir: ../data_for_train/TN/labels_detect
# ...

# %%
# os.chdir('./code_seg')
# os.getcwd()

# %%
# !sh run_seg.sh
